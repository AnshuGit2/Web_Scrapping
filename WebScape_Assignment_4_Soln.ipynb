# %% [markdown]
# # ISYS613 - Data Sourcing and Quality
# # Assignment 4
# ## Web Scraping

# %% [markdown]
# ## Question 1 - Book Data Scraper
#
# You have been asked to collect some price data about books from the Books to Scrape website.
# Specifically, you are to scrape and capture the following book related information - book category,
# book title, star rating and price. Once captured, you are to output your results to a CSV file.
# ```
# Top-Level URL: http://books.toscrape.com/
# ```
#
# ### Requirements
# 1. Examine the HTML returned from the Books to Scrape top-level URL.
#  Your objective is to identify and extract book category and the book
#  category URL information from this page.
# 2. For each book category URL, follow the URL to the book category
#  page. You may restrict your data scraping to the first page of books
#  returned for the category URL.
# 3. For each of the books on a category page, capture the book title,
#  star rating and price.
# 4. Convert the ordinal star rating data to a numeric scale. For
#  example, the string 'star-rating One' would be converted to the integer number
#  1, 'star-rating Two' would be converted to 2, and so on.
# 5. For each book, output the book category, title, numeric star rating and price.
#
# ### Challenge (Optional)
# The challenge objective is to display all books (formatted as above) from all categories - not
#  just the first page of books from each category.  To see how this works, go the
#  top-level URL and observe how to
#  manually navigate from the first page of a category to the next, then next, etc. until you have
#  followed the Next link to all pages for a category.
#
# Notice that book data from a category URL is returned 20 books at a time. If there more than
# 20 books in category, the Next link appears at the bottom of the HTML page.
# When the list of books in a category has been exhausted, ie., when the last
# category page has been reached, the Next link will no longer appear on the page.
#
# Hint: That's how you will know your job is complete.
#
# Copy your previous solution to a new code-cell. Modify your copied solution to follow
# the Next page links located at the bottom of a category page.

# %%
from requests.exceptions import HTTPError
import requests
from bs4 import BeautifulSoup
import re
from pprint import pprint
from urllib.parse import urljoin

def simple_get(url, params=None):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None.
    """
    try:
        resp = requests.get(url, timeout=5, params=params)
        # If the response was successful, no Exception will be raised
        resp.raise_for_status()

    except HTTPError as http_err:
        print(f'HTTP error occurred: {http_err}')
        raise http_err
    except Exception as err:
        print(f'Other error occurred: {err}')
        raise err
    else:
        # sanity check
        # is this HTML?
        content_type = resp.headers['Content-Type'].lower()
        # True if the response seems to be HTML, False otherwise.
        # Followed by 'death'
        assert content_type.find('html') >= 0

    return resp

def book_category_contents(url, cat_list):
    
    resp = simple_get(url)
    # get the decoded payload.  the text() method uses metadata to devine encoding.
    html = resp.text
    soup = BeautifulSoup(html, 'html.parser')
    
    # CHALLENGE:
    # Recursively call book_category_contents() for all pages cat pages.
    # Looking for HTML
    # <li class="next"><a href="page-2.html">next</a></li>
    #
    li = soup.find('li', class_='next')
    if li is not None:      
        pgurl = urljoin(url, li.a['href'])       
        book_category_contents(pgurl, cat_list)
    

    '''
    # The following example chunk of HTML contains all
    # the data we need for each book in a category
    #
    <article class="product_pod">

            <div class="image_container">
                    <a href="..
            </div>
                <p class="star-rating One">
                .
                </p>
            <h3><a href="../../../
            <div class="product_price">
        <p class="price_color">Â£30.54</p>
    </article>
    '''
    star_list = ['One', 'Two', 'Three', 'Four', 'Five']

    for art in soup.find_all('article', class_=re.compile(r'^product_pod$')):

        # fetch title
        # Note: the <h3> tag contains a abbreviated title so don't use that

        div = art.find('div', class_='image_container')
        title = div.a.img['alt']

        # fetch star rating info
        regex = re.compile(r'^star-rating\s+(One|Two|Three|Four|Five)$')
        star = art.find('p', class_=regex)

        # the class attr of star-rating is two words separated by space and therefore the
        # the 'class' attr is returned as a list of words
        # Ex: ['star-rating', 'One']
        #
        cls_list = star['class']
        assert isinstance(cls_list, list)
        star_rating = star['class'][1]
        star_rating = star_list.index( star_rating ) + 1

        # fetch price info
        price_str = art.find('p', class_='price_color').text

        # use re to remove any chars that are
        # not \d (digit) or decimal place (dot)

        price = re.sub(r'[^\d.]', '', price_str)
        cat_dict = {'title': title, 'star_rating': star_rating, 'price': price}
        cat_list.append( cat_dict )


# The following function is actually a 'generator' function
# because of the use of the yield statement.  See below.
# A generator is sometimes called a 'lazy iterator'
# because it procrastinates work until absolutely necessary.
# So, instead of gobbling up all the categories and keeping them in
# a list, this generator will return a category and its url one
# at a time as they are requested.  That is, this function is iterable. If there were a
# large number of categories it might even be worth the effort!
#
# See http://naiquevin.github.io/python-generators-and-being-lazy.html

def book_categories(url):

    resp = simple_get(url)

    # get the decoded payload.
    # The text property uses HTTP or HTML metadata to devine encoding.
    html = resp.text

    # By inspection of HTTP on the URL we can see
    # the book cats are in an unordered list list (<ul> )
    # that has a class of "nav nav-list". We could use this
    # to drill down the right spot; however, there is a better
    # pattern.  Each book cat is an anchor tag (<a>) with an href
    # attribute that always begins (and ends - which is significant
    # w.r.t. the pattern) with the same text: 'catalogue/category/books/.../index.html'
    # Ex: <a href="catalogue/category/books/travel_2/index.html">
    # Time to write a RE!
    #
    soup = BeautifulSoup(html, 'html.parser')

    # Note: category urls can be composed of
    # characters in the character class:  [-_\w\d/]

    for anchor in soup.find_all('a', href= re.compile(r'^catalogue/category/books/[-_\w\d/]+/index[.]html$')):
        # the text for each <a> contains the category data
        cat = anchor.text.strip()
        url = anchor['href'].strip()

        # The use yield makes this function a generator function (aka 'lazy-iterator')
        # The yield effectively creates a snapshot of the state of this function
        # followed by the  return the cat, url tuple.
        # When the function is called again, the state of
        # the fuction is restored and the loop picks up where it left off. Pretty neat - IMO.
        # See https://realpython.com/introduction-to-python-generators/
        yield cat, url

def main():
    # Get the book categories and cat URLs from top-level URL
    BOOK_URL = 'http://books.toscrape.com/'

    # book_categories() is a generator function. See comment
    # above the function def
    #
    for c,u in book_categories(BOOK_URL):
        # create a list to hold book info for category.
        # Pass list as argument to func book_category_contents().
        # The reason the list is an argument (and not returned by the function)
        # is because the book_category_contents() function
        # recursively follows the 'next page' links.
        #
        cat_list = []
        cat_url = urljoin(BOOK_URL, u)
        
        book_category_contents(cat_url, cat_list)

        # at this point, cat_list will have been updated
        # to be a list of book related dictionaries of the following type:
        # {'title': title, 'star_rating': star_rating, 'price': price}
        # The keys in this dict need to be identical to the field names
        # expected by the csv.DictWriter object (if you planned to print the results).

        # display data
        for d in cat_list:
            # add category key to the dict
            d['category'] = c
            pprint(d, indent=2)

if __name__ == '__main__':
    main()
# Out:
# { 'category': 'Travel',
#   'price': '45.17',
#   'star_rating': 2,
#   'title': "It's Only the Himalayas"}
# { 'category': 'Travel',
#   'price': '49.43',
#   'star_rating': 4,
#   'title': 'Full Moon over Noahâ\x80\x99s Ark: An Odyssey to Mount Ararat and '
#            'Beyond'}
# { 'category': 'Travel',
#   'price': '48.87',
#   'star_rating': 3,
#   'title': 'See America: A Celebration of Our National Parks & Treasured Sites'}
# { 'category': 'Travel',
#   'price': '36.94',
#   'star_rating': 2,
#   'title': 'Vagabonding: An Uncommon Guide to the Art of Long-Term World '
#            'Travel'}
# { 'category': 'Travel',
#   'price': '37.33',
#   'star_rating': 3,
#   'title': 'Under the Tuscan Sun'}
# { 'category': 'Travel',
#   'price': '44.34',
#   'star_rating': 2,
#   'title': 'A Summer In Europe'}
# { 'category': 'Travel',
#   'price': '30.54',
#   'star_rating': 1,
#   'title': 'The Great Railway Bazaar'}
# { 'category': 'Travel',
#   'price': '56.88',
#   'star_rating': 4,
#   'title': 'A Year in Provence (Provence #1)'}
# { 'category': 'Travel',
#   'price': '23.21',
#   'star_rating': 1,
#   'title': 'The Road to Little Dribbling: Adventures of an American in Britain '
#            '(Notes From a Small Island #2)'}
# { 'category': 'Travel',
#   'price': '38.95',
#   'star_rating': 3,
#   'title': 'Neither Here nor There: Travels in Europe'}
# { 'category': 'Travel',
#   'price': '26.08',
#   'star_rating': 5,
#   'title': '1,000 Places to See Before You Die'}
# { 'category': 'Mystery',
#   'price': '24.80',
#   'star_rating': 4,
#   'title': 'The Mysterious Affair at Styles (Hercule Poirot #1)'}
# { 'category': 'Mystery',
#   'price': '38.38',
#   'star_rating': 2,
#   'title': 'In the Woods (Dublin Murder Squad #1)'}
# { 'category': 'Mystery',
#   'price': '23.05',
#   'star_rating': 5,
#   'title': 'The Silkworm (Cormoran Strike #2)'}
# { 'category': 'Mystery',
#   'price': '43.45',
#   'star_rating': 3,
#   'title': 'The Exiled'}
# { 'category': 'Mystery',
#   'price': '19.21',
#   'star_rating': 1,
#   'title': "The Cuckoo's Calling (Cormoran Strike #1)"}
# { 'category': 'Mystery',
#   'price': '25.40',
#   'star_rating': 3,
#   'title': 'Extreme Prey (Lucas Davenport #26)'}
# { 'category': 'Mystery',
#   'price': '24.72',
#   'star_rating': 2,
#   'title': 'Career of Evil (Cormoran Strike #3)'}
# { 'category': 'Mystery',
#   'price': '57.70',
#   'star_rating': 4,
#   'title': "The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency "
#            '#1)'}
# { 'category': 'Mystery',
#   'price': '12.29',
#   'star_rating': 5,
#   'title': 'The Girl You Lost'}
# { 'category': 'Mystery',
#   'price': '15.85',
#   'star_rating': 3,
#   'title': 'The Girl In The Ice (DCI Erika Foster #1)'}
# { 'category': 'Mystery',
#   'price': '20.30',
#   'star_rating': 3,
#   'title': 'Blood Defense (Samantha Brinkman #1)'}
# { 'category': 'Mystery',
#   'price': '53.98',
#   'star_rating': 1,
#   'title': "1st to Die (Women's Murder Club #1)"}
# { 'category': 'Mystery',
#   'price': '47.82',
#   'star_rating': 4,
#   'title': 'Sharp Objects'}
# { 'category': 'Mystery',
#   'price': '19.63',
#   'star_rating': 1,
#   'title': 'In a Dark, Dark Wood'}
# { 'category': 'Mystery',
#   'price': '56.50',
#   'star_rating': 4,
#   'title': 'The Past Never Ends'}
# { 'category': 'Mystery',
#   'price': '16.64',
#   'star_rating': 1,
#   'title': 'A Murder in Time'}
# { 'category': 'Mystery',
#   'price': '44.10',
#   'star_rating': 4,
#   'title': 'The Murder of Roger Ackroyd (Hercule Poirot #4)'}
# { 'category': 'Mystery',
#   'price': '54.21',
#   'star_rating': 2,
#   'title': 'The Last Mile (Amos Decker #2)'}
# { 'category': 'Mystery',
#   'price': '13.92',
#   'star_rating': 1,
#   'title': 'That Darkness (Gardiner and Renner #1)'}
# { 'category': 'Mystery',
#   'price': '10.69',
#   'star_rating': 1,
#   'title': 'Tastes Like Fear (DI Marnie Rome #3)'}
# { 'category': 'Mystery',
#   'price': '48.35',
#   'star_rating': 5,
#   'title': 'A Time of Torment (Charlie Parker #14)'}
# { 'category': 'Mystery',
#   'price': '16.73',
#   'star_rating': 2,
#   'title': 'A Study in Scarlet (Sherlock Holmes #1)'}
# { 'category': 'Mystery',
#   'price': '26.80',
#   'star_rating': 3,
#   'title': 'Poisonous (Max Revere Novels #3)'}
# { 'category': 'Mystery',
#   'price': '54.36',
#   'star_rating': 4,
#   'title': 'Murder at the 42nd Street Library (Raymond Ambler #1)'}
# { 'category': 'Mystery',
#   'price': '35.28',
#   'star_rating': 3,
#   'title': 'Most Wanted'}
# { 'category': 'Mystery',
#   'price': '11.84',
#   'star_rating': 1,
#   'title': 'Hide Away (Eve Duncan #20)'}
# { 'category': 'Mystery',
#   'price': '59.48',
#   'star_rating': 3,
#   'title': 'Boar Island (Anna Pigeon #19)'}
# { 'category': 'Mystery',
#   'price': '27.26',
#   'star_rating': 2,
#   'title': 'The Widow'}
# { 'category': 'Mystery',
#   'price': '13.71',
#   'star_rating': 3,
#   'title': 'Playing with Fire'}
# { 'category': 'Mystery',
#   'price': '25.37',
#   'star_rating': 5,
#   'title': 'What Happened on Beale Street (Secrets of the South Mysteries #2)'}
# { 'category': 'Mystery',
#   'price': '52.30',
#   'star_rating': 5,
#   'title': "The Bachelor Girl's Guide to Murder (Herringford and Watts "
#            'Mysteries #1)'}
# { 'category': 'Mystery',
#   'price': '20.89',
#   'star_rating': 4,
#   'title': 'Delivering the Truth (Quaker Midwife Mystery #1)'}
# { 'category': 'Historical Fiction',
#   'price': '20.79',
#   'star_rating': 5,
#   'title': 'Between Shades of Gray'}
# { 'category': 'Historical Fiction',
#   'price': '41.32',
#   'star_rating': 5,
#   'title': 'While You Were Mine'}
# { 'category': 'Historical Fiction',
#   'price': '34.56',
#   'star_rating': 3,
#   'title': 'The Secret Healer'}
# { 'category': 'Historical Fiction',
#   'price': '25.83',
#   'star_rating': 3,
#   'title': 'Starlark'}
# { 'category': 'Historical Fiction',
#   'price': '27.70',
#   'star_rating': 4,
#   'title': 'Lost Among the Living'}
# { 'category': 'Historical Fiction',
#   'price': '16.97',
#   'star_rating': 5,
#   'title': "A Spy's Devotion (The Regency Spies of London #1)"}
# { 'category': 'Historical Fiction',
#   'price': '53.74',
#   'star_rating': 1,
#   'title': 'Tipping the Velvet'}
# { 'category': 'Historical Fiction',
#   'price': '29.69',
#   'star_rating': 3,
#   'title': 'Forever and Forever: The Courtship of Henry Longfellow and Fanny '
#            'Appleton'}
# { 'category': 'Historical Fiction',
#   'price': '55.53',
#   'star_rating': 5,
#   'title': 'A Flight of Arrows (The Pathfinders #2)'}
# { 'category': 'Historical Fiction',
#   'price': '36.95',
#   'star_rating': 1,
#   'title': 'The House by the Lake'}
# { 'category': 'Historical Fiction',
#   'price': '30.25',
#   'star_rating': 5,
#   'title': 'Mrs. Houdini'}
# { 'category': 'Historical Fiction',
#   'price': '28.08',
#   'star_rating': 4,
#   'title': 'The Marriage of Opposites'}
# { 'category': 'Historical Fiction',
#   'price': '45.84',
#   'star_rating': 3,
#   'title': 'Glory over Everything: Beyond The Kitchen House'}
# { 'category': 'Historical Fiction',
#   'price': '20.55',
#   'star_rating': 2,
#   'title': 'Love, Lies and Spies'}
# { 'category': 'Historical Fiction',
#   'price': '39.01',
#   'star_rating': 4,
#   'title': 'A Paris Apartment'}
# { 'category': 'Historical Fiction',
#   'price': '17.28',
#   'star_rating': 2,
#   'title': 'Lilac Girls'}
# { 'category': 'Historical Fiction',
#   'price': '16.62',
#   'star_rating': 3,
#   'title': 'The Constant Princess (The Tudor Court #1)'}
# { 'category': 'Historical Fiction',
#   'price': '37.34',
#   'star_rating': 1,
#   'title': 'The Invention of Wings'}
# { 'category': 'Historical Fiction',
#   'price': '32.97',
#   'star_rating': 4,
#   'title': 'World Without End (The Pillars of the Earth #2)'}
# { 'category': 'Historical Fiction',
#   'price': '28.32',
#   'star_rating': 5,
#   'title': 'The Passion of Dolssa'}
# { 'category': 'Historical Fiction',
#   'price': '26.77',
#   'star_rating': 1,
#   'title': 'Girl With a Pearl Earring'}
# { 'category': 'Historical Fiction',
#   'price': '21.07',
#   'star_rating': 5,
#   'title': 'Voyager (Outlander #3)'}
# { 'category': 'Historical Fiction',
#   'price': '35.66',
#   'star_rating': 5,
#   'title': 'The Red Tent'}
# { 'category': 'Historical Fiction',
#   'price': '55.55',
#   'star_rating': 2,
#   'title': 'The Last Painting of Sara de Vos'}
# { 'category': 'Historical Fiction',
#   'price': '49.53',
#   'star_rating': 1,
#   'title': 'The Guernsey Literary and Potato Peel Pie Society'}
# { 'category': 'Historical Fiction',
#   'price': '46.83',
#   'star_rating': 2,
#   'title': 'Girl in the Blue Coat'}
# { 'category': 'Sequential Art',
#   'price': '18.51',
#   'star_rating': 4,
#   'title': 'Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1)'}
# { 'category': 'Sequential Art',
#   'price': '36.52',
#   'star_rating': 2,
#   'title': 'The Wicked + The Divine, Vol. 1: The Faust Act (The Wicked + The '
#            'Divine)'}
# { 'category': 'Sequential Art',
#   'price': '54.12',
#   'star_rating': 3,
#   'title': 'The Sandman, Vol. 1: Preludes and Nocturnes (The Sandman (volumes) '
#            '#1)'}
# { 'category': 'Sequential Art',
#   'price': '10.64',
#   'star_rating': 3,
#   'title': 'The Complete Maus (Maus #1-2)'}
# { 'category': 'Sequential Art',
#   'price': '42.12',
#   'star_rating': 3,
#   'title': 'Skip Beat!, Vol. 01 (Skip Beat! #1)'}
# { 'category': 'Sequential Art',
#   'price': '28.48',
#   'star_rating': 1,
#   'title': 'Saga, Volume 1 (Saga (Collected Editions) #1)'}
# { 'category': 'Sequential Art',
#   'price': '46.96',
#   'star_rating': 5,
#   'title': 'Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected '
#            'Editions) #1-5)'}
# { 'category': 'Sequential Art',
#   'price': '21.71',
#   'star_rating': 4,
#   'title': 'Paper Girls, Vol. 1 (Paper Girls #1-5)'}
# { 'category': 'Sequential Art',
#   'price': '29.87',
#   'star_rating': 3,
#   'title': 'Ouran High School Host Club, Vol. 1 (Ouran High School Host Club '
#            '#1)'}
# { 'category': 'Sequential Art',
#   'price': '39.39',
#   'star_rating': 4,
#   'title': 'Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)'}
# { 'category': 'Sequential Art',
#   'price': '45.24',
#   'star_rating': 3,
#   'title': 'Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1)'}
# { 'category': 'Sequential Art',
#   'price': '56.76',
#   'star_rating': 4,
#   'title': 'Giant Days, Vol. 1 (Giant Days #1-4)'}
# { 'category': 'Sequential Art',
#   'price': '40.28',
#   'star_rating': 5,
#   'title': 'Fruits Basket, Vol. 1 (Fruits Basket #1)'}
# { 'category': 'Sequential Art',
#   'price': '34.65',
#   'star_rating': 5,
#   'title': 'Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)'}
# { 'category': 'Sequential Art',
#   'price': '57.06',
#   'star_rating': 4,
#   'title': 'Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)'}
# { 'category': 'Sequential Art',
#   'price': '19.57',
#   'star_rating': 1,
#   'title': 'Fruits Basket, Vol. 7 (Fruits Basket #7)'}
# { 'category': 'Sequential Art',
#   'price': '20.96',
#   'star_rating': 4,
#   'title': 'Fruits Basket, Vol. 6 (Fruits Basket #6)'}
# { 'category': 'Sequential Art',
#   'price': '36.39',
#   'star_rating': 3,
#   'title': 'Death Note, Vol. 6: Give-and-Take (Death Note #6)'}
# { 'category': 'Sequential Art',
#   'price': '16.33',
#   'star_rating': 1,
#   'title': 'Fruits Basket, Vol. 5 (Fruits Basket #5)'}
# { 'category': 'Sequential Art',
#   'price': '52.41',
#   'star_rating': 1,
#   'title': 'Death Note, Vol. 5: Whiteout (Death Note #5)'}
# { 'category': 'Sequential Art',
#   'price': '27.88',
#   'star_rating': 2,
#   'title': 'The Demon Prince of Momochi House, Vol. 4 (The Demon Prince of '
#            'Momochi House #4)'}
# { 'category': 'Sequential Art',
#   'price': '50.44',
#   'star_rating': 4,
#   'title': 'Fruits Basket, Vol. 4 (Fruits Basket #4)'}
# { 'category': 'Sequential Art',
#   'price': '14.41',
#   'star_rating': 3,
#   'title': 'The Wicked + The Divine, Vol. 3: Commercial Suicide (The Wicked + '
#            'The Divine)'}
# { 'category': 'Sequential Art',
#   'price': '55.55',
#   'star_rating': 5,
#   'title': 'The Sandman, Vol. 3: Dream Country (The Sandman (volumes) #3)'}
# { 'category': 'Sequential Art',
#   'price': '21.57',
#   'star_rating': 5,
#   'title': 'Saga, Volume 3 (Saga (Collected Editions) #3)'}
# { 'category': 'Sequential Art',
#   'price': '43.63',
#   'star_rating': 3,
#   'title': 'Prodigy: The Graphic Novel (Legend: The Graphic Novel #2)'}
# { 'category': 'Sequential Art',
#   'price': '39.13',
#   'star_rating': 1,
#   'title': 'Persepolis: The Story of a Childhood (Persepolis #1-2)'}
# { 'category': 'Sequential Art',
#   'price': '31.45',
#   'star_rating': 3,
#   'title': 'Original Fake'}
# { 'category': 'Sequential Art',
#   'price': '42.72',
#   'star_rating': 1,
#   'title': 'Grayson, Vol 3: Nemesis (Grayson #3)'}
# { 'category': 'Sequential Art',
#   'price': '45.17',
#   'star_rating': 2,
#   'title': 'Fruits Basket, Vol. 3 (Fruits Basket #3)'}
# { 'category': 'Sequential Art',
#   'price': '49.31',
#   'star_rating': 1,
#   'title': 'Black Butler, Vol. 1 (Black Butler #1)'}
# { 'category': 'Sequential Art',
#   'price': '38.02',
#   'star_rating': 2,
#   'title': 'Awkward'}
# { 'category': 'Sequential Art',
#   'price': '54.81',
#   'star_rating': 1,
#   'title': "The Sandman, Vol. 2: The Doll's House (The Sandman (volumes) #2)"}
# { 'category': 'Sequential Art',
#   'price': '11.75',
#   'star_rating': 3,
#   'title': 'Saga, Volume 2 (Saga (Collected Editions) #2)'}
# { 'category': 'Sequential Art',
#   'price': '11.64',
#   'star_rating': 5,
#   'title': 'Fruits Basket, Vol. 2 (Fruits Basket #2)'}
# { 'category': 'Sequential Art',
#   'price': '37.92',
#   'star_rating': 2,
#   'title': 'Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet '
#            '(Collected Editions))'}
# { 'category': 'Sequential Art',
#   'price': '33.14',
#   'star_rating': 1,
#   'title': 'The Shadow Hero (The Shadow Hero)'}
# { 'category': 'Sequential Art',
#   'price': '41.62',
#   'star_rating': 4,
#   'title': 'Fables, Vol. 1: Legends in Exile (Fables #1)'}
# { 'category': 'Sequential Art',
#   'price': '36.50',
#   'star_rating': 2,
#   'title': 'Batman: The Long Halloween (Batman)'}
# { 'category': 'Sequential Art',
#   'price': '15.38',
#   'star_rating': 5,
#   'title': 'Batman: The Dark Knight Returns (Batman)'}
# { 'category': 'Sequential Art',
#   'price': '37.34',
#   'star_rating': 4,
#   'title': 'Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)'}
# { 'category': 'Sequential Art',
#   'price': '53.90',
#   'star_rating': 1,
#   'title': 'We Are Robin, Vol. 1: The Vigilante Business (We Are Robin #1)'}
# { 'category': 'Sequential Art',
#   'price': '25.38',
#   'star_rating': 2,
#   'title': 'Through the Woods'}
# { 'category': 'Sequential Art',
#   'price': '11.89',
#   'star_rating': 5,
#   'title': 'Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1)'}
# { 'category': 'Sequential Art',
#   'price': '35.43',
#   'star_rating': 4,
#   'title': 'So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6)'}
# { 'category': 'Sequential Art',
#   'price': '47.82',
#   'star_rating': 3,
#   'title': 'Robin War'}
# { 'category': 'Sequential Art',
#   'price': '25.48',
#   'star_rating': 2,
#   'title': 'Red Hood/Arsenal, Vol. 1: Open for Business (Red Hood/Arsenal #1)'}
# { 'category': 'Sequential Art',
#   'price': '38.39',
#   'star_rating': 2,
#   'title': 'Naruto (3-in-1 Edition), Vol. 14: Includes Vols. 40, 41 & 42 '
#            '(Naruto: Omnibus #14)'}
# { 'category': 'Sequential Art',
#   'price': '51.51',
#   'star_rating': 2,
#   'title': 'Lowriders to the Center of the Earth (Lowriders in Space #2)'}
# { 'category': 'Sequential Art',
#   'price': '57.62',
#   'star_rating': 5,
#   'title': 'El Deafo'}
# { 'category': 'Sequential Art',
#   'price': '32.01',
#   'star_rating': 2,
#   'title': 'Batman: Europa'}
# { 'category': 'Sequential Art',
#   'price': '48.80',
#   'star_rating': 3,
#   'title': 'Art Ops Vol. 1'}
# { 'category': 'Sequential Art',
#   'price': '10.90',
#   'star_rating': 2,
#   'title': 'Adulthood Is a Myth: A "Sarah\'s Scribbles" Collection'}
# { 'category': 'Sequential Art',
#   'price': '33.95',
#   'star_rating': 4,
#   'title': 'Fruits Basket, Vol. 9 (Fruits Basket #9)'}
# { 'category': 'Sequential Art',
#   'price': '14.10',
#   'star_rating': 5,
#   'title': 'Roller Girl'}
# { 'category': 'Sequential Art',
#   'price': '52.29',
#   'star_rating': 5,
#   'title': "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)"}
# { 'category': 'Sequential Art',
#   'price': '16.28',
#   'star_rating': 1,
#   'title': 'Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)'}
# { 'category': 'Sequential Art',
#   'price': '19.49',
#   'star_rating': 4,
#   'title': 'This One Summer'}
# { 'category': 'Sequential Art',
#   'price': '38.16',
#   'star_rating': 4,
#   'title': 'The Nameless City (The Nameless City #1)'}
# { 'category': 'Sequential Art',
#   'price': '51.04',
#   'star_rating': 2,
#   'title': 'Saga, Volume 5 (Saga (Collected Editions) #5)'}
# { 'category': 'Sequential Art',
#   'price': '50.40',
#   'star_rating': 3,
#   'title': 'Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) '
#            '#11-15)'}
# { 'category': 'Sequential Art',
#   'price': '13.61',
#   'star_rating': 5,
#   'title': 'Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish '
#            '2-in-1 Omnibus #1)'}
# { 'category': 'Sequential Art',
#   'price': '18.97',
#   'star_rating': 1,
#   'title': 'Pop Gun War, Volume 1: Gift'}
# { 'category': 'Sequential Art',
#   'price': '10.16',
#   'star_rating': 3,
#   'title': 'Patience'}
# { 'category': 'Sequential Art',
#   'price': '15.44',
#   'star_rating': 4,
#   'title': 'Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)'}
# { 'category': 'Sequential Art',
#   'price': '48.41',
#   'star_rating': 1,
#   'title': 'orange: The Complete Collection 1 (orange: The Complete Collection '
#            '#1)'}
# { 'category': 'Sequential Art',
#   'price': '46.91',
#   'star_rating': 2,
#   'title': 'Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)'}
# { 'category': 'Sequential Art',
#   'price': '45.61',
#   'star_rating': 3,
#   'title': 'Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)'}
# { 'category': 'Sequential Art',
#   'price': '19.92',
#   'star_rating': 2,
#   'title': 'Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)'}
# { 'category': 'Sequential Art',
#   'price': '29.17',
#   'star_rating': 2,
#   'title': 'I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland '
#            '(Compilations) #1-5)'}
# { 'category': 'Sequential Art',
#   'price': '54.63',
#   'star_rating': 3,
#   'title': 'I am a Hero Omnibus Volume 1'}
# { 'category': 'Sequential Art',
#   'price': '22.11',
#   'star_rating': 2,
#   'title': 'Giant Days, Vol. 2 (Giant Days #5-8)'}
# { 'category': 'Sequential Art',
#   'price': '51.99',
#   'star_rating': 4,
#   'title': 'Danganronpa Volume 1'}
# { 'category': 'Sequential Art',
#   'price': '36.72',
#   'star_rating': 4,
#   'title': 'Codename Baboushka, Volume 1: The Conclave of Death'}
# { 'category': 'Sequential Art',
#   'price': '17.08',
#   'star_rating': 4,
#   'title': 'Camp Midnight'}
# { 'category': 'Classics',
#   'price': '15.08',
#   'star_rating': 4,
#   'title': 'The Secret Garden'}
# { 'category': 'Classics',
#   'price': '28.58',
#   'star_rating': 1,
#   'title': 'The Metamorphosis'}
# { 'category': 'Classics',
#   'price': '50.26',
#   'star_rating': 2,
#   'title': "The Pilgrim's Progress"}
# { 'category': 'Classics',
#   'price': '14.82',
#   'star_rating': 2,
#   'title': 'The Hound of the Baskervilles (Sherlock Holmes #5)'}
# { 'category': 'Classics',
#   'price': '28.07',
#   'star_rating': 4,
#   'title': 'Little Women (Little Women #1)'}
# { 'category': 'Classics',
#   'price': '32.49',
#   'star_rating': 3,
#   'title': 'Gone with the Wind'}
# {'category': 'Classics', 'price': '58.63', 'star_rating': 3, 'title': 'Candide'}
# { 'category': 'Classics',
#   'price': '57.22',
#   'star_rating': 3,
#   'title': 'Animal Farm'}
# { 'category': 'Classics',
#   'price': '17.73',
#   'star_rating': 3,
#   'title': 'Wuthering Heights'}
# { 'category': 'Classics',
#   'price': '29.70',
#   'star_rating': 2,
#   'title': 'The Picture of Dorian Gray'}
# { 'category': 'Classics',
#   'price': '26.78',
#   'star_rating': 4,
#   'title': 'The Complete Stories and Poems (The Works of Edgar Allan Poe '
#            '[Cameo Edition])'}
# {'category': 'Classics', 'price': '38.35', 'star_rating': 2, 'title': 'Beowulf'}
# { 'category': 'Classics',
#   'price': '35.01',
#   'star_rating': 2,
#   'title': 'And Then There Were None'}
# { 'category': 'Classics',
#   'price': '43.19',
#   'star_rating': 4,
#   'title': 'The Story of Hong Gildong'}
# { 'category': 'Classics',
#   'price': '45.42',
#   'star_rating': 2,
#   'title': 'The Little Prince'}
# { 'category': 'Classics',
#   'price': '37.46',
#   'star_rating': 1,
#   'title': 'Sense and Sensibility'}
# { 'category': 'Classics',
#   'price': '47.11',
#   'star_rating': 2,
#   'title': 'Of Mice and Men'}
# {'category': 'Classics', 'price': '32.93', 'star_rating': 2, 'title': 'Emma'}
# { 'category': 'Classics',
#   'price': '55.53',
#   'star_rating': 1,
#   'title': "Alice in Wonderland (Alice's Adventures in Wonderland #1)"}
# { 'category': 'Philosophy',
#   'price': '15.94',
#   'star_rating': 5,
#   'title': "Sophie's World"}
# { 'category': 'Philosophy',
#   'price': '58.11',
#   'star_rating': 4,
#   'title': 'The Death of Humanity: and the Case for Life'}
# { 'category': 'Philosophy',
#   'price': '17.44',
#   'star_rating': 4,
#   'title': 'The Stranger'}
# { 'category': 'Philosophy',
#   'price': '54.21',
#   'star_rating': 1,
#   'title': 'Proofs of God: Classical Arguments from Tertullian to Barth'}
# { 'category': 'Philosophy',
#   'price': '47.13',
#   'star_rating': 1,
#   'title': 'Kierkegaard: A Christian Missionary to Christians'}
# { 'category': 'Philosophy',
#   'price': '29.93',
#   'star_rating': 5,
#   'title': 'At The Existentialist CafÃ©: Freedom, Being, and apricot cocktails '
#            'with: Jean-Paul Sartre, Simone de Beauvoir, Albert Camus, Martin '
#            'Heidegger, Edmund Husserl, Karl Jaspers, Maurice Merleau-Ponty and '
#            'others'}
# { 'category': 'Philosophy',
#   'price': '20.75',
#   'star_rating': 1,
#   'title': 'Critique of Pure Reason'}
# { 'category': 'Philosophy',
#   'price': '20.02',
#   'star_rating': 1,
#   'title': 'Run, Spot, Run: The Ethics of Keeping Pets'}
# { 'category': 'Philosophy',
#   'price': '36.34',
#   'star_rating': 1,
#   'title': 'The Nicomachean Ethics'}
# { 'category': 'Philosophy',
#   'price': '25.89',
#   'star_rating': 2,
#   'title': 'Meditations'}
# { 'category': 'Philosophy',
#   'price': '43.38',
#   'star_rating': 1,
#   'title': 'Beyond Good and Evil'}
# { 'category': 'Romance',
#   'price': '56.43',
#   'star_rating': 1,
#   'title': 'A Walk to Remember'}
# { 'category': 'Romance',
#   'price': '12.25',
#   'star_rating': 1,
#   'title': 'The Purest Hook (Second Circle Tattoos #3)'}
# { 'category': 'Romance',
#   'price': '45.43',
#   'star_rating': 1,
#   'title': 'The Obsession'}
# { 'category': 'Romance',
#   'price': '11.10',
#   'star_rating': 3,
#   'title': 'Reservations for Two'}
# { 'category': 'Romance',
#   'price': '27.41',
#   'star_rating': 2,
#   'title': "Best of My Love (Fool's Gold #20)"}
# { 'category': 'Romance',
#   'price': '39.77',
#   'star_rating': 3,
#   'title': 'Where Lightning Strikes (Bleeding Stars #3)'}
# { 'category': 'Romance',
#   'price': '48.71',
#   'star_rating': 1,
#   'title': 'This One Moment (Pushing Limits #1)'}
# { 'category': 'Romance',
#   'price': '28.34',
#   'star_rating': 2,
#   'title': 'Rhythm, Chord & Malykhin'}
# { 'category': 'Romance',
#   'price': '38.92',
#   'star_rating': 2,
#   'title': 'My Perfect Mistake (Over the Top #1)'}
# { 'category': 'Romance',
#   'price': '58.99',
#   'star_rating': 3,
#   'title': 'Listen to Me (Fusion #1)'}
# { 'category': 'Romance',
#   'price': '34.74',
#   'star_rating': 4,
#   'title': 'Imperfect Harmony'}
# { 'category': 'Romance',
#   'price': '39.24',
#   'star_rating': 3,
#   'title': 'Fighting Fate (Fighting #6)'}
# { 'category': 'Romance',
#   'price': '47.09',
#   'star_rating': 5,
#   'title': 'Deep Under (Walker Security #1)'}
# { 'category': 'Romance',
#   'price': '41.24',
#   'star_rating': 1,
#   'title': "Charity's Cross (Charles Towne Belles #4)"}
# { 'category': 'Romance',
#   'price': '37.26',
#   'star_rating': 4,
#   'title': 'Bounty (Colorado Mountain #7)'}
# { 'category': 'Romance',
#   'price': '25.27',
#   'star_rating': 5,
#   'title': 'Chase Me (Paris Nights #2)'}
# { 'category': 'Romance',
#   'price': '34.53',
#   'star_rating': 5,
#   'title': 'Black Dust'}
# { 'category': 'Romance',
#   'price': '33.97',
#   'star_rating': 1,
#   'title': 'Her Backup Boyfriend (The Sorensen Family #1)'}
# { 'category': 'Romance',
#   'price': '15.97',
#   'star_rating': 4,
#   'title': 'First and First (Five Boroughs #3)'}
# { 'category': 'Romance',
#   'price': '21.96',
#   'star_rating': 1,
#   'title': 'Fifty Shades Darker (Fifty Shades #2)'}
# { 'category': 'Romance',
#   'price': '24.12',
#   'star_rating': 1,
#   'title': 'The Wedding Dress'}
# { 'category': 'Romance',
#   'price': '55.99',
#   'star_rating': 2,
#   'title': 'Suddenly in Love (Lake Haven #1)'}
# { 'category': 'Romance',
#   'price': '16.24',
#   'star_rating': 4,
#   'title': 'Something More Than This'}
# { 'category': 'Romance',
#   'price': '35.61',
#   'star_rating': 3,
#   'title': 'Doing It Over (Most Likely To #1)'}
# { 'category': 'Romance',
#   'price': '32.61',
#   'star_rating': 3,
#   'title': "The Wedding Pact (The O'Malleys #2)"}
# { 'category': 'Romance',
#   'price': '28.82',
#   'star_rating': 1,
#   'title': 'Hold Your Breath (Search and Rescue #1)'}
# { 'category': 'Romance',
#   'price': '40.83',
#   'star_rating': 4,
#   'title': 'Dirty (Dive Bar #1)'}
# { 'category': 'Romance',
#   'price': '53.98',
#   'star_rating': 3,
#   'title': 'Take Me Home Tonight (Rock Star Romance #3)'}
# { 'category': 'Romance',
#   'price': '47.67',
#   'star_rating': 3,
#   'title': 'Off the Hook (Fishing for Trouble #1)'}
# { 'category': 'Romance',
#   'price': '14.75',
#   'star_rating': 5,
#   'title': "A Gentleman's Position (Society of Gentlemen #3)"}
# { 'category': 'Romance',
#   'price': '20.90',
#   'star_rating': 3,
#   'title': 'Sit, Stay, Love'}
# { 'category': 'Romance',
#   'price': '31.30',
#   'star_rating': 1,
#   'title': "A Girl's Guide to Moving On (New Beginnings #2)"}
# { 'category': 'Romance',
#   'price': '59.99',
#   'star_rating': 3,
#   'title': 'The Perfect Play (Play by Play #1)'}
# { 'category': 'Romance',
#   'price': '12.87',
#   'star_rating': 1,
#   'title': 'Dark Lover (Black Dagger Brotherhood #1)'}
# { 'category': 'Romance',
#   'price': '13.38',
#   'star_rating': 3,
#   'title': 'Changing the Game (Play by Play #2)'}
# { 'category': 'Womens Fiction',
#   'price': '57.36',
#   'star_rating': 4,
#   'title': 'I Had a Nice Time And Other Lies...: How to find love & sh*t like '
#            'that'}
# { 'category': 'Womens Fiction',
#   'price': '13.86',
#   'star_rating': 3,
#   'title': "Will You Won't You Want Me?"}
# { 'category': 'Womens Fiction',
#   'price': '20.46',
#   'star_rating': 4,
#   'title': 'Keep Me Posted'}
# { 'category': 'Womens Fiction',
#   'price': '48.49',
#   'star_rating': 4,
#   'title': 'Grey (Fifty Shades #4)'}
# { 'category': 'Womens Fiction',
#   'price': '43.58',
#   'star_rating': 3,
#   'title': 'Meternity'}
# { 'category': 'Womens Fiction',
#   'price': '13.73',
#   'star_rating': 5,
#   'title': 'Some Women'}
# { 'category': 'Womens Fiction',
#   'price': '48.39',
#   'star_rating': 5,
#   'title': 'Shopaholic Ties the Knot (Shopaholic #3)'}
# { 'category': 'Womens Fiction',
#   'price': '21.94',
#   'star_rating': 1,
#   'title': 'Can You Keep a Secret?'}
# { 'category': 'Womens Fiction',
#   'price': '42.80',
#   'star_rating': 2,
#   'title': 'Twenties Girl'}
# { 'category': 'Womens Fiction',
#   'price': '45.75',
#   'star_rating': 4,
#   'title': 'The Undomestic Goddess'}
# { 'category': 'Womens Fiction',
#   'price': '52.53',
#   'star_rating': 5,
#   'title': 'The Nanny Diaries (Nanny #1)'}
# { 'category': 'Womens Fiction',
#   'price': '44.29',
#   'star_rating': 1,
#   'title': 'The Devil Wears Prada (The Devil Wears Prada #1)'}
# { 'category': 'Womens Fiction',
#   'price': '48.96',
#   'star_rating': 5,
#   'title': 'Something Borrowed (Darcy & Rachel #1)'}
# { 'category': 'Womens Fiction',
#   'price': '54.62',
#   'star_rating': 1,
#   'title': 'Something Blue (Darcy & Rachel #2)'}
# { 'category': 'Womens Fiction',
#   'price': '19.69',
#   'star_rating': 1,
#   'title': "I've Got Your Number"}
# { 'category': 'Womens Fiction',
#   'price': '19.18',
#   'star_rating': 4,
#   'title': 'The Edge of Reason (Bridget Jones #2)'}
# { 'category': 'Womens Fiction',
#   'price': '29.82',
#   'star_rating': 1,
#   'title': "Bridget Jones's Diary (Bridget Jones #1)"}
# { 'category': 'Fiction',
#   'price': '51.96',
#   'star_rating': 3,
#   'title': "When I'm Gone"}
# { 'category': 'Fiction',
#   'price': '12.34',
#   'star_rating': 5,
#   'title': 'The Silent Wife'}
# { 'category': 'Fiction',
#   'price': '30.66',
#   'star_rating': 3,
#   'title': 'The Bette Davis Club'}
# { 'category': 'Fiction',
#   'price': '57.20',
#   'star_rating': 5,
#   'title': 'Kitchens of the Great Midwest'}
# { 'category': 'Fiction',
#   'price': '39.07',
#   'star_rating': 5,
#   'title': 'Bright Lines'}
# { 'category': 'Fiction',
#   'price': '40.32',
#   'star_rating': 4,
#   'title': 'Deception Point'}
# { 'category': 'Fiction',
#   'price': '24.73',
#   'star_rating': 3,
#   'title': 'The Little Paris Bookshop'}
# {'category': 'Fiction', 'price': '45.56', 'star_rating': 3, 'title': 'The Firm'}
# { 'category': 'Fiction',
#   'price': '44.58',
#   'star_rating': 2,
#   'title': 'The Expatriates'}
# { 'category': 'Fiction',
#   'price': '34.22',
#   'star_rating': 5,
#   'title': 'Siddhartha'}
# { 'category': 'Fiction',
#   'price': '59.98',
#   'star_rating': 3,
#   'title': 'Last One Home (New Beginnings #1)'}
# { 'category': 'Fiction',
#   'price': '58.00',
#   'star_rating': 5,
#   'title': 'Digital Fortress'}
# { 'category': 'Fiction',
#   'price': '26.58',
#   'star_rating': 5,
#   'title': 'Atlas Shrugged'}
# { 'category': 'Fiction',
#   'price': '23.21',
#   'star_rating': 3,
#   'title': 'Three-Martini Lunch'}
# { 'category': 'Fiction',
#   'price': '26.26',
#   'star_rating': 4,
#   'title': 'The Nightingale'}
# { 'category': 'Fiction',
#   'price': '27.41',
#   'star_rating': 1,
#   'title': 'The Infinities'}
# { 'category': 'Fiction',
#   'price': '52.51',
#   'star_rating': 5,
#   'title': "The Husband's Secret"}
# { 'category': 'Fiction',
#   'price': '22.96',
#   'star_rating': 2,
#   'title': 'The Da Vinci Code (Robert Langdon #2)'}
# { 'category': 'Fiction',
#   'price': '22.10',
#   'star_rating': 1,
#   'title': 'The Art of Fielding'}
# { 'category': 'Fiction',
#   'price': '12.47',
#   'star_rating': 3,
#   'title': 'Lila (Gilead #3)'}
# { 'category': 'Fiction',
#   'price': '44.97',
#   'star_rating': 1,
#   'title': 'Jurassic Park (Jurassic Park #1)'}
# { 'category': 'Fiction',
#   'price': '41.00',
#   'star_rating': 5,
#   'title': 'Inferno (Robert Langdon #4)'}
# { 'category': 'Fiction',
#   'price': '49.13',
#   'star_rating': 5,
#   'title': 'Crazy Rich Asians (Crazy Rich Asians #1)'}
# { 'category': 'Fiction',
#   'price': '22.11',
#   'star_rating': 1,
#   'title': 'Big Little Lies'}
# { 'category': 'Fiction',
#   'price': '16.78',
#   'star_rating': 3,
#   'title': 'The Course of Love'}
# { 'category': 'Fiction',
#   'price': '14.39',
#   'star_rating': 4,
#   'title': 'Eight Hundred Grapes'}
# { 'category': 'Fiction',
#   'price': '11.21',
#   'star_rating': 5,
#   'title': 'Dear Mr. Knightley'}
# { 'category': 'Fiction',
#   'price': '25.01',
#   'star_rating': 3,
#   'title': 'Cometh the Hour (The Clifton Chronicles #6)'}
# { 'category': 'Fiction',
#   'price': '17.03',
#   'star_rating': 3,
#   'title': 'Balloon Animals'}
# { 'category': 'Fiction',
#   'price': '39.72',
#   'star_rating': 1,
#   'title': 'A Man Called Ove'}
# { 'category': 'Fiction',
#   'price': '46.29',
#   'star_rating': 5,
#   'title': 'The Silent Sister (Riley MacPherson #1)'}
# { 'category': 'Fiction',
#   'price': '56.54',
#   'star_rating': 2,
#   'title': 'The Dinner Party'}
# { 'category': 'Fiction',
#   'price': '59.45',
#   'star_rating': 1,
#   'title': 'The Improbability of Love'}
# { 'category': 'Fiction',
#   'price': '13.34',
#   'star_rating': 2,
#   'title': 'Mothering Sunday'}
# { 'category': 'Fiction',
#   'price': '45.14',
#   'star_rating': 1,
#   'title': 'Lies and Other Acts of Love'}
# { 'category': 'Fiction',
#   'price': '16.34',
#   'star_rating': 3,
#   'title': 'Daredevils'}
# {'category': 'Fiction', 'price': '48.48', 'star_rating': 3, 'title': '11/22/63'}
# { 'category': 'Fiction',
#   'price': '28.03',
#   'star_rating': 1,
#   'title': 'The Shack'}
# { 'category': 'Fiction',
#   'price': '51.15',
#   'star_rating': 1,
#   'title': 'The High Mountains of Portugal'}
# { 'category': 'Fiction',
#   'price': '58.54',
#   'star_rating': 2,
#   'title': "Miller's Valley"}
# { 'category': 'Fiction',
#   'price': '21.96',
#   'star_rating': 4,
#   'title': 'Hystopia: A Novel'}
# { 'category': 'Fiction',
#   'price': '42.78',
#   'star_rating': 4,
#   'title': 'The Bourne Identity (Jason Bourne #1)'}
# { 'category': 'Fiction',
#   'price': '40.20',
#   'star_rating': 4,
#   'title': 'Sister Dear'}
# { 'category': 'Fiction',
#   'price': '49.67',
#   'star_rating': 3,
#   'title': 'Memoirs of a Geisha'}
# { 'category': 'Fiction',
#   'price': '19.02',
#   'star_rating': 1,
#   'title': 'Me Before You (Me Before You #1)'}
# { 'category': 'Fiction',
#   'price': '50.10',
#   'star_rating': 1,
#   'title': 'Soumission'}
# { 'category': 'Fiction',
#   'price': '47.61',
#   'star_rating': 5,
#   'title': 'Private Paris (Private #10)'}
# { 'category': 'Fiction',
#   'price': '50.27',
#   'star_rating': 5,
#   'title': 'We Love You, Charlie Freeman'}
# {'category': 'Fiction', 'price': '17.27', 'star_rating': 5, 'title': 'Thirst'}
# { 'category': 'Fiction',
#   'price': '54.11',
#   'star_rating': 3,
#   'title': 'The Murder That Never Was (Forensic Instincts #5)'}
# { 'category': 'Fiction',
#   'price': '21.04',
#   'star_rating': 2,
#   'title': 'Tuesday Nights in 1980'}
# { 'category': 'Fiction',
#   'price': '42.15',
#   'star_rating': 4,
#   'title': 'The Vacationers'}
# { 'category': 'Fiction',
#   'price': '51.36',
#   'star_rating': 5,
#   'title': 'The Regional Office Is Under Attack!'}
# { 'category': 'Fiction',
#   'price': '53.53',
#   'star_rating': 5,
#   'title': 'Finders Keepers (Bill Hodges Trilogy #2)'}
# { 'category': 'Fiction',
#   'price': '27.88',
#   'star_rating': 5,
#   'title': 'The Time Keeper'}
# { 'category': 'Fiction',
#   'price': '52.67',
#   'star_rating': 4,
#   'title': 'The Testament of Mary'}
# { 'category': 'Fiction',
#   'price': '25.85',
#   'star_rating': 3,
#   'title': 'The First Hostage (J.B. Collins #2)'}
# { 'category': 'Fiction',
#   'price': '45.21',
#   'star_rating': 3,
#   'title': 'Take Me with You'}
# { 'category': 'Fiction',
#   'price': '26.41',
#   'star_rating': 3,
#   'title': 'Still Life with Bread Crumbs'}
# {'category': 'Fiction', 'price': '55.84', 'star_rating': 4, 'title': 'Shtum'}
# { 'category': 'Fiction',
#   'price': '41.56',
#   'star_rating': 1,
#   'title': 'My Name Is Lucy Barton'}
# { 'category': 'Fiction',
#   'price': '24.48',
#   'star_rating': 3,
#   'title': 'My Mrs. Brown'}
# { 'category': 'Fiction',
#   'price': '28.90',
#   'star_rating': 1,
#   'title': 'Mr. Mercedes (Bill Hodges Trilogy #1)'}
# { 'category': 'Fiction',
#   'price': '10.60',
#   'star_rating': 4,
#   'title': 'I Am Pilgrim (Pilgrim #1)'}
# { 'category': 'Fiction',
#   'price': '27.09',
#   'star_rating': 3,
#   'title': 'Eligible (The Austen Project #4)'}
# { 'category': 'Childrens',
#   'price': '16.26',
#   'star_rating': 2,
#   'title': 'The Cat in the Hat (Beginner Books B-1)'}
# { 'category': 'Childrens',
#   'price': '28.54',
#   'star_rating': 3,
#   'title': 'Red: The True Story of Red Riding Hood'}
# { 'category': 'Childrens',
#   'price': '37.52',
#   'star_rating': 2,
#   'title': 'Horrible Bear!'}
# { 'category': 'Childrens',
#   'price': '10.79',
#   'star_rating': 4,
#   'title': 'Green Eggs and Ham (Beginner Books B-16)'}
# { 'category': 'Childrens',
#   'price': '10.62',
#   'star_rating': 1,
#   'title': 'Counting Thyme'}
# { 'category': 'Childrens',
#   'price': '10.66',
#   'star_rating': 3,
#   'title': 'Are We There Yet?'}
# { 'category': 'Childrens',
#   'price': '52.88',
#   'star_rating': 4,
#   'title': 'Diary of a Minecraft Zombie Book 1: A Scare of a Dare (An '
#            'Unofficial Minecraft Book)'}
# { 'category': 'Childrens',
#   'price': '28.34',
#   'star_rating': 1,
#   'title': 'Matilda'}
# { 'category': 'Childrens',
#   'price': '22.85',
#   'star_rating': 3,
#   'title': 'Charlie and the Chocolate Factory (Charlie Bucket #1)'}
# { 'category': 'Childrens',
#   'price': '54.64',
#   'star_rating': 3,
#   'title': 'Birdsong: A Story in Pictures'}
# { 'category': 'Childrens',
#   'price': '36.89',
#   'star_rating': 1,
#   'title': 'The Bear and the Piano'}
# { 'category': 'Childrens',
#   'price': '56.13',
#   'star_rating': 1,
#   'title': 'The Secret of Dreadwillow Carse'}
# { 'category': 'Childrens',
#   'price': '58.08',
#   'star_rating': 4,
#   'title': 'The White Cat and the Monk: A Retelling of the Poem '
#            'â\x80\x9cPangur BÃ¡nâ\x80\x9d'}
# { 'category': 'Childrens',
#   'price': '13.47',
#   'star_rating': 3,
#   'title': 'Little Red'}
# { 'category': 'Childrens',
#   'price': '12.96',
#   'star_rating': 5,
#   'title': "Walt Disney's Alice in Wonderland"}
# { 'category': 'Childrens',
#   'price': '22.08',
#   'star_rating': 2,
#   'title': 'Twenty Yawns'}
# { 'category': 'Childrens',
#   'price': '23.57',
#   'star_rating': 3,
#   'title': 'Rain Fish'}
# { 'category': 'Childrens',
#   'price': '18.28',
#   'star_rating': 2,
#   'title': 'Once Was a Time'}
# { 'category': 'Childrens',
#   'price': '53.95',
#   'star_rating': 3,
#   'title': 'Luis Paints the World'}
# { 'category': 'Childrens',
#   'price': '25.08',
#   'star_rating': 1,
#   'title': 'Nap-a-Roo'}
# { 'category': 'Childrens',
#   'price': '35.96',
#   'star_rating': 4,
#   'title': 'The Whale'}
# { 'category': 'Childrens',
#   'price': '52.87',
#   'star_rating': 3,
#   'title': 'Shrunken Treasures: Literary Classics, Short, Sweet, and Silly'}
# { 'category': 'Childrens',
#   'price': '34.41',
#   'star_rating': 2,
#   'title': 'Raymie Nightingale'}
# { 'category': 'Childrens',
#   'price': '32.38',
#   'star_rating': 1,
#   'title': 'Playing from the Heart'}
# { 'category': 'Childrens',
#   'price': '22.54',
#   'star_rating': 1,
#   'title': 'Maybe Something Beautiful: How Art Transformed a Neighborhood'}
# { 'category': 'Childrens',
#   'price': '56.07',
#   'star_rating': 3,
#   'title': 'The Wild Robot'}
# { 'category': 'Childrens',
#   'price': '48.77',
#   'star_rating': 1,
#   'title': 'The Thing About Jellyfish'}
# { 'category': 'Childrens',
#   'price': '43.59',
#   'star_rating': 5,
#   'title': 'The Lonely Ones'}
# { 'category': 'Childrens',
#   'price': '26.33',
#   'star_rating': 5,
#   'title': 'The Day the Crayons Came Home (Crayons)'}
# { 'category': 'Religion',
#   'price': '37.97',
#   'star_rating': 2,
#   'title': "Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's "
#            'Greatest Zen Master'}
# { 'category': 'Religion',
#   'price': '21.87',
#   'star_rating': 4,
#   'title': 'You Are What You Love: The Spiritual Power of Habit'}
# { 'category': 'Religion',
#   'price': '30.03',
#   'star_rating': 5,
#   'title': 'God: The Most Unpleasant Character in All Fiction'}
# { 'category': 'Religion',
#   'price': '24.57',
#   'star_rating': 3,
#   'title': 'The Book of Mormon'}
# { 'category': 'Religion',
#   'price': '27.62',
#   'star_rating': 1,
#   'title': 'A History of God: The 4,000-Year Quest of Judaism, Christianity, '
#            'and Islam'}
# { 'category': 'Religion',
#   'price': '57.49',
#   'star_rating': 3,
#   'title': 'The Bhagavad Gita'}
# { 'category': 'Religion',
#   'price': '28.42',
#   'star_rating': 4,
#   'title': "Choosing Our Religion: The Spiritual Lives of America's Nones"}
# { 'category': 'Nonfiction',
#   'price': '40.87',
#   'star_rating': 1,
#   'title': 'Black Flags: The Rise of ISIS'}
# { 'category': 'Nonfiction',
#   'price': '56.58',
#   'star_rating': 1,
#   'title': 'Are We Smart Enough to Know How Smart Animals Are?'}
# { 'category': 'Nonfiction',
#   'price': '30.48',
#   'star_rating': 4,
#   'title': 'A Walk in the Woods: Rediscovering America on the Appalachian '
#            'Trail'}
# { 'category': 'Nonfiction',
#   'price': '11.89',
#   'star_rating': 2,
#   'title': 'The Suffragettes (Little Black Classics, #96)'}
# { 'category': 'Nonfiction',
#   'price': '34.00',
#   'star_rating': 3,
#   'title': "Kindle Paperwhite User's Guide"}
# { 'category': 'Nonfiction',
#   'price': '57.42',
#   'star_rating': 5,
#   'title': 'H is for Hawk'}
# { 'category': 'Nonfiction',
#   'price': '57.82',
#   'star_rating': 5,
#   'title': 'Travels with Charley: In Search of America'}
# { 'category': 'Nonfiction',
#   'price': '41.56',
#   'star_rating': 5,
#   'title': 'The Tumor'}
# { 'category': 'Nonfiction',
#   'price': '14.40',
#   'star_rating': 1,
#   'title': 'The End of the Jesus Era (An Investigation #1)'}
# { 'category': 'Nonfiction',
#   'price': '51.32',
#   'star_rating': 3,
#   'title': 'Eat, Pray, Love'}
# { 'category': 'Nonfiction',
#   'price': '53.51',
#   'star_rating': 1,
#   'title': "Trespassing Across America: One Man's Epic, Never-Done-Before (and "
#            'Sort of Illegal) Hike Across the Heartland'}
# { 'category': 'Nonfiction',
#   'price': '37.25',
#   'star_rating': 2,
#   'title': 'The Name of God is Mercy'}
# { 'category': 'Nonfiction',
#   'price': '36.74',
#   'star_rating': 3,
#   'title': 'Stiff: The Curious Lives of Human Cadavers'}
# { 'category': 'Nonfiction',
#   'price': '49.51',
#   'star_rating': 1,
#   'title': 'Spilled Milk: Based on a True Story'}
# { 'category': 'Nonfiction',
#   'price': '41.67',
#   'star_rating': 4,
#   'title': 'Rise of the Rocket Girls: The Women Who Propelled Us, from '
#            'Missiles to the Moon to Mars'}
# { 'category': 'Nonfiction',
#   'price': '14.16',
#   'star_rating': 1,
#   'title': 'Outliers: The Story of Success'}
# { 'category': 'Nonfiction',
#   'price': '40.17',
#   'star_rating': 1,
#   'title': 'Notes from a Small Island (Notes From a Small Island #1)'}
# { 'category': 'Nonfiction',
#   'price': '13.51',
#   'star_rating': 1,
#   'title': 'Night (The Night Trilogy #1)'}
# { 'category': 'Nonfiction',
#   'price': '57.83',
#   'star_rating': 1,
#   'title': 'Miracles from Heaven: A Little Girl, Her Journey to Heaven, and '
#            'Her Amazing Story of Healing'}
# { 'category': 'Nonfiction',
#   'price': '22.20',
#   'star_rating': 1,
#   'title': 'Letter to a Christian Nation'}
# { 'category': 'Nonfiction',
#   'price': '45.11',
#   'star_rating': 1,
#   'title': "Let's Pretend This Never Happened: A Mostly True Memoir"}
# { 'category': 'Nonfiction',
#   'price': '42.38',
#   'star_rating': 1,
#   'title': "It's Never Too Late to Begin Again: Discovering Creativity and "
#            'Meaning at Midlife and Beyond'}
# { 'category': 'Nonfiction',
#   'price': '56.70',
#   'star_rating': 5,
#   'title': 'Into the Wild'}
# { 'category': 'Nonfiction',
#   'price': '28.85',
#   'star_rating': 3,
#   'title': 'In the Garden of Beasts: Love, Terror, and an American Family in '
#            "Hitler's Berlin"}
# { 'category': 'Nonfiction',
#   'price': '28.88',
#   'star_rating': 2,
#   'title': 'I Am Malala: The Girl Who Stood Up for Education and Was Shot by '
#            'the Taliban'}
# { 'category': 'Nonfiction',
#   'price': '26.66',
#   'star_rating': 5,
#   'title': 'Gratitude'}
# { 'category': 'Nonfiction',
#   'price': '15.28',
#   'star_rating': 5,
#   'title': 'Disrupted: My Misadventure in the Start-Up Bubble'}
# { 'category': 'Nonfiction',
#   'price': '51.32',
#   'star_rating': 5,
#   'title': 'Brave Enough'}
# { 'category': 'Nonfiction',
#   'price': '27.35',
#   'star_rating': 2,
#   'title': 'Born to Run: A Hidden Tribe, Superathletes, and the Greatest Race '
#            'the World Has Never Seen'}
# { 'category': 'Nonfiction',
#   'price': '21.74',
#   'star_rating': 5,
#   'title': 'Blink: The Power of Thinking Without Thinking'}
# { 'category': 'Nonfiction',
#   'price': '56.91',
#   'star_rating': 4,
#   'title': 'Between the World and Me'}
# { 'category': 'Nonfiction',
#   'price': '55.06',
#   'star_rating': 4,
#   'title': 'Being Mortal: Medicine and What Matters in the End'}
# { 'category': 'Nonfiction',
#   'price': '13.20',
#   'star_rating': 3,
#   'title': 'A Murder Over a Girl: Justice, Gender, Junior High'}
# { 'category': 'Nonfiction',
#   'price': '45.13',
#   'star_rating': 3,
#   'title': 'For the Love: Fighting for Grace in a World of Impossible '
#            'Standards'}
# { 'category': 'Nonfiction',
#   'price': '46.64',
#   'star_rating': 2,
#   'title': 'Finding God in the Ruins: How God Redeems Pain'}
# { 'category': 'Nonfiction',
#   'price': '59.45',
#   'star_rating': 4,
#   'title': 'The Man Who Mistook His Wife for a Hat and Other Clinical Tales'}
# { 'category': 'Nonfiction',
#   'price': '49.98',
#   'star_rating': 4,
#   'title': 'In Cold Blood'}
# { 'category': 'Nonfiction',
#   'price': '42.14',
#   'star_rating': 3,
#   'title': 'Girl, Interrupted'}
# { 'category': 'Nonfiction',
#   'price': '48.67',
#   'star_rating': 2,
#   'title': 'Why Save the Bankers?: And Other Essays on Our Economic and '
#            'Political Crisis'}
# { 'category': 'Nonfiction',
#   'price': '25.15',
#   'star_rating': 4,
#   'title': "Talking to Girls About Duran Duran: One Young Man's Quest for True "
#            'Love and a Cooler Haircut'}
# { 'category': 'Nonfiction',
#   'price': '31.63',
#   'star_rating': 4,
#   'title': 'My Mother Was Nuts'}
# { 'category': 'Nonfiction',
#   'price': '32.35',
#   'star_rating': 3,
#   'title': 'Data, A Love Story: How I Gamed Online Dating to Meet My Match'}
# { 'category': 'Nonfiction',
#   'price': '38.71',
#   'star_rating': 3,
#   'title': 'The Jazz of Physics: The Secret Link Between Music and the '
#            'Structure of the Universe'}
# { 'category': 'Nonfiction',
#   'price': '16.81',
#   'star_rating': 4,
#   'title': 'The Gunning of America: Business and the Making of American Gun '
#            'Culture'}
# { 'category': 'Nonfiction',
#   'price': '28.23',
#   'star_rating': 2,
#   'title': "The Geography of Bliss: One Grump's Search for the Happiest Places "
#            'in the World'}
# { 'category': 'Nonfiction',
#   'price': '27.80',
#   'star_rating': 1,
#   'title': 'God Is Not Great: How Religion Poisons Everything'}
# { 'category': 'Nonfiction',
#   'price': '31.95',
#   'star_rating': 3,
#   'title': 'We the People: The Modern-Day Figures Who Have Reshaped and '
#            "Affirmed the Founding Fathers' Vision of America"}
# { 'category': 'Nonfiction',
#   'price': '50.66',
#   'star_rating': 3,
#   'title': 'Very Good Lives: The Fringe Benefits of Failure and the Importance '
#            'of Imagination'}
# { 'category': 'Nonfiction',
#   'price': '58.09',
#   'star_rating': 1,
#   'title': 'Unstuffed: Decluttering Your Home, Mind, and Soul'}
# { 'category': 'Nonfiction',
#   'price': '30.00',
#   'star_rating': 1,
#   'title': 'Under the Banner of Heaven: A Story of Violent Faith'}
# { 'category': 'Nonfiction',
#   'price': '33.26',
#   'star_rating': 2,
#   'title': 'The Lonely City: Adventures in the Art of Being Alone'}
# { 'category': 'Nonfiction',
#   'price': '59.90',
#   'star_rating': 3,
#   'title': 'The Diary of a Young Girl'}
# { 'category': 'Nonfiction',
#   'price': '21.21',
#   'star_rating': 3,
#   'title': 'Snatched: How A Drug Queen Went Undercover for the DEA and Was '
#            'Kidnapped By Colombian Guerillas'}
# { 'category': 'Nonfiction',
#   'price': '41.46',
#   'star_rating': 4,
#   'title': 'Furiously Happy: A Funny Book About Horrible Things'}
# { 'category': 'Nonfiction',
#   'price': '11.68',
#   'star_rating': 4,
#   'title': 'The Sleep Revolution: Transforming Your Life, One Night at a Time'}
# { 'category': 'Nonfiction',
#   'price': '16.89',
#   'star_rating': 5,
#   'title': 'Mother, Can You Not?'}
# { 'category': 'Nonfiction',
#   'price': '19.53',
#   'star_rating': 3,
#   'title': "A Mother's Reckoning: Living in the Aftermath of Tragedy"}
# { 'category': 'Nonfiction',
#   'price': '24.57',
#   'star_rating': 2,
#   'title': '10% Happier: How I Tamed the Voice in My Head, Reduced Stress '
#            'Without Losing My Edge, and Found Self-Help That Actually Works'}
# { 'category': 'Nonfiction',
#   'price': '35.92',
#   'star_rating': 2,
#   'title': "Chernobyl 01:23:40: The Incredible True Story of the World's Worst "
#            'Nuclear Disaster'}
# { 'category': 'Nonfiction',
#   'price': '34.06',
#   'star_rating': 3,
#   'title': 'Zero to One: Notes on Startups, or How to Build the Future'}
# { 'category': 'Nonfiction',
#   'price': '17.76',
#   'star_rating': 1,
#   'title': 'Why Not Me?'}
# { 'category': 'Nonfiction',
#   'price': '39.36',
#   'star_rating': 2,
#   'title': 'When Breath Becomes Air'}
# { 'category': 'Nonfiction',
#   'price': '28.45',
#   'star_rating': 4,
#   'title': "The Midnight Assassin: Panic, Scandal, and the Hunt for America's "
#            'First Serial Killer'}
# { 'category': 'Nonfiction',
#   'price': '38.89',
#   'star_rating': 5,
#   'title': 'Smarter Faster Better: The Secrets of Being Productive in Life and '
#            'Business'}
# { 'category': 'Nonfiction',
#   'price': '21.82',
#   'star_rating': 3,
#   'title': 'Rising Strong'}
# { 'category': 'Nonfiction',
#   'price': '29.48',
#   'star_rating': 3,
#   'title': "Man's Search for Meaning"}
# { 'category': 'Nonfiction',
#   'price': '25.06',
#   'star_rating': 2,
#   'title': 'Love That Boy: What Two Presidents, Eight Road Trips, and My Son '
#            "Taught Me About a Parent's Expectations"}
# { 'category': 'Nonfiction',
#   'price': '12.55',
#   'star_rating': 3,
#   'title': 'Living Forward: A Proven Plan to Stop Drifting and Get the Life '
#            'You Want'}
# { 'category': 'Nonfiction',
# ...
# { 'category': 'History',
#   'price': '36.28',
#   'star_rating': 2,
#   'title': 'Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom '
#            'Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes '
#            'in the Annals of American Politics'}
# { 'category': 'History',
#   'price': '59.64',
#   'star_rating': 1,
#   'title': 'Thomas Jefferson and the Tripoli Pirates: The Forgotten War That '
#            'Changed American History'}
# { 'category': 'History',
#   'price': '24.70',
#   'star_rating': 3,
#   'title': 'Zealot: The Life and Times of Jesus of Nazareth'}
# { 'category': 'History',
#   'price': '14.58',
#   'star_rating': 3,
#   'title': 'A Distant Mirror: The Calamitous 14th Century'}
# { 'category': 'History',
#   'price': '21.80',
#   'star_rating': 3,
#   'title': '1491: New Revelations of the Americas Before Columbus'}
# { 'category': 'History',
#   'price': '11.45',
#   'star_rating': 3,
#   'title': 'Brilliant Beacons: A History of the American Lighthouse'}
# { 'category': 'History',
#   'price': '44.48',
#   'star_rating': 5,
#   'title': '"Most Blessed of the Patriarchs": Thomas Jefferson and the Empire '
#            'of the Imagination'}
# { 'category': 'History',
#   'price': '52.40',
#   'star_rating': 5,
#   'title': 'A Short History of Nearly Everything'}
# { 'category': 'History',
#   'price': '39.67',
#   'star_rating': 2,
#   'title': 'The Rise and Fall of the Third Reich: A History of Nazi Germany'}
# { 'category': 'History',
#   'price': '58.55',
#   'star_rating': 4,
#   'title': 'Catherine the Great: Portrait of a Woman'}
# { 'category': 'History',
#   'price': '42.91',
#   'star_rating': 5,
#   'title': "The Mathews Men: Seven Brothers and the War Against Hitler's "
#            'U-boats'}
# { 'category': 'History',
#   'price': '55.91',
#   'star_rating': 4,
#   'title': 'The Hiding Place'}
# { 'category': 'History',
#   'price': '51.22',
#   'star_rating': 2,
#   'title': "America's War for the Greater Middle East: A Military History"}
# { 'category': 'History',
#   'price': '14.54',
#   'star_rating': 2,
#   'title': 'The Guns of August'}
# { 'category': 'History',
#   'price': '43.70',
#   'star_rating': 2,
#   'title': 'House of Lost Worlds: Dinosaurs, Dynasties, and the Story of Life '
#            'on Earth'}
# { 'category': 'Food and Drink',
#   'price': '46.01',
#   'star_rating': 4,
#   'title': 'How to Cook Everything Vegetarian: Simple Meatless Recipes for '
#            'Great Food (How to Cook Everything)'}
# { 'category': 'Food and Drink',
#   'price': '28.25',
#   'star_rating': 2,
#   'title': 'How to Be a Domestic Goddess: Baking and the Art of Comfort '
#            'Cooking'}
# { 'category': 'Food and Drink',
#   'price': '59.92',
#   'star_rating': 5,
#   'title': 'The Barefoot Contessa Cookbook'}
# { 'category': 'Food and Drink',
#   'price': '39.61',
#   'star_rating': 3,
#   'title': 'Better Homes and Gardens New Cook Book'}
# { 'category': 'Food and Drink',
#   'price': '11.05',
#   'star_rating': 5,
#   'title': 'The Power Greens Cookbook: 140 Delicious Superfood Recipes'}
# { 'category': 'Food and Drink',
#   'price': '24.91',
#   'star_rating': 5,
#   'title': 'Mexican Today: New and Rediscovered Recipes for Contemporary '
#            'Kitchens'}
# { 'category': 'Food and Drink',
#   'price': '13.66',
#   'star_rating': 2,
#   'title': 'Vegan Vegetarian Omnivore: Dinner for Everyone at the Table'}
# { 'category': 'Food and Drink',
#   'price': '23.59',
#   'star_rating': 1,
#   'title': 'The Smitten Kitchen Cookbook'}
# { 'category': 'Food and Drink',
#   'price': '34.32',
#   'star_rating': 3,
#   'title': 'The Art of Simple Food: Notes, Lessons, and Recipes from a '
#            'Delicious Revolution'}
# { 'category': 'Food and Drink',
#   'price': '33.14',
#   'star_rating': 3,
#   'title': 'Hungry Girl Clean & Hungry: Easy All-Natural Recipes for Healthy '
#            'Eating in the Real World'}
# { 'category': 'Food and Drink',
#   'price': '30.52',
#   'star_rating': 3,
#   'title': 'Foolproof Preserving: A Guide to Small Batch Jams, Jellies, '
#            'Pickles, Condiments, and More: A Foolproof Guide to Making Small '
#            'Batch Jams, Jellies, Pickles, Condiments, and More'}
# { 'category': 'Food and Drink',
#   'price': '56.41',
#   'star_rating': 1,
#   'title': 'The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer '
#            'Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!'}
# { 'category': 'Food and Drink',
#   'price': '33.37',
#   'star_rating': 2,
#   'title': 'My Paris Kitchen: Recipes and Stories'}
# { 'category': 'Food and Drink',
#   'price': '14.02',
#   'star_rating': 4,
#   'title': 'Mama Tried: Traditional Italian Cooking for the Screwed, Crude, '
#            'Vegan, and Tattooed'}
# { 'category': 'Food and Drink',
#   'price': '40.11',
#   'star_rating': 1,
#   'title': 'Layered: Baking, Building, and Styling Spectacular Cakes'}
# { 'category': 'Food and Drink',
#   'price': '37.34',
#   'star_rating': 5,
#   'title': 'The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us'}
# { 'category': 'Food and Drink',
#   'price': '37.60',
#   'star_rating': 2,
#   'title': 'The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of '
#            'Impromptu Cooking'}
# { 'category': 'Food and Drink',
#   'price': '41.25',
#   'star_rating': 1,
#   'title': 'The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding '
#            'you to Always Eat Dessert First'}
# { 'category': 'Food and Drink',
#   'price': '42.16',
#   'star_rating': 3,
#   'title': 'Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free '
#            'Snacks, Packed Lunches, and Simple Meals'}
# { 'category': 'Food and Drink',
#   'price': '28.77',
#   'star_rating': 3,
#   'title': 'The Help Yourself Cookbook for Kids: 60 Easy Plant-Based Recipes '
#            'Kids Can Make to Stay Healthy and Save the Earth'}
# { 'category': 'Food and Drink',
#   'price': '19.55',
#   'star_rating': 1,
#   'title': "It's All Easy: Healthy, Delicious Weeknight Meals in under 30 "
#            'Minutes'}
# { 'category': 'Food and Drink',
#   'price': '28.01',
#   'star_rating': 1,
#   'title': 'Barefoot Contessa Back to Basics'}
# { 'category': 'Food and Drink',
#   'price': '50.62',
#   'star_rating': 5,
#   'title': "Barefoot Contessa at Home: Everyday Recipes You'll Make Over and "
#            'Over Again'}
# { 'category': 'Food and Drink',
#   'price': '11.53',
#   'star_rating': 2,
#   'title': 'My Kitchen Year: 136 Recipes That Saved My Life'}
# { 'category': 'Food and Drink',
#   'price': '20.10',
#   'star_rating': 5,
#   'title': 'Everyday Italian: 125 Simple and Delicious Recipes'}
# { 'category': 'Food and Drink',
#   'price': '38.77',
#   'star_rating': 1,
#   'title': 'A la Mode: 120 Recipes in 60 Pairings: Pies, Tarts, Cakes, Crisps, '
#            'and More Topped with Ice Cream, Gelato, Frozen Custard, and More'}
# { 'category': 'Food and Drink',
#   'price': '20.50',
#   'star_rating': 3,
#   'title': 'Cravings: Recipes for What You Want to Eat'}
# { 'category': 'Food and Drink',
#   'price': '12.34',
#   'star_rating': 4,
#   'title': 'The Moosewood Cookbook: Recipes from Moosewood Restaurant, Ithaca, '
#            'New York'}
# { 'category': 'Food and Drink',
#   'price': '53.63',
#   'star_rating': 2,
#   'title': '32 Yolks'}
# { 'category': 'Food and Drink',
#   'price': '11.38',
#   'star_rating': 5,
#   'title': 'Naturally Lean: 125 Nourishing Gluten-Free, Plant-Based '
#            'Recipes--All Under 300 Calories'}
# { 'category': 'Christian Fiction',
#   'price': '20.47',
#   'star_rating': 5,
#   'title': 'Redeeming Love'}
# { 'category': 'Christian Fiction',
#   'price': '49.46',
#   'star_rating': 4,
#   'title': 'Close to You'}
# { 'category': 'Christian Fiction',
#   'price': '39.67',
#   'star_rating': 5,
#   'title': 'Shadows of the Past (Logan Point #1)'}
# { 'category': 'Christian Fiction',
#   'price': '28.77',
#   'star_rating': 2,
#   'title': 'Like Never Before (Walker Family #2)'}
# { 'category': 'Christian Fiction',
#   'price': '17.97',
#   'star_rating': 5,
#   'title': 'Counted With the Stars (Out from Egypt #1)'}
# { 'category': 'Christian Fiction',
#   'price': '49.97',
#   'star_rating': 4,
#   'title': 'If I Run (If I Run #1)'}
# { 'category': 'Business',
#   'price': '33.34',
#   'star_rating': 4,
#   'title': 'The Dirty Little Secrets of Getting Your Dream Job'}
# { 'category': 'Business',
#   'price': '12.61',
#   'star_rating': 5,
#   'title': 'The Third Wave: An Entrepreneurâ\x80\x99s Vision of the Future'}
# { 'category': 'Business',
#   'price': '27.55',
#   'star_rating': 3,
#   'title': 'The 10% Entrepreneur: Live Your Startup Dream Without Quitting '
#            'Your Day Job'}
# { 'category': 'Business',
#   'price': '23.99',
#   'star_rating': 2,
#   'title': 'Shoe Dog: A Memoir by the Creator of NIKE'}
# { 'category': 'Business',
#   'price': '38.85',
#   'star_rating': 5,
#   'title': 'Made to Stick: Why Some Ideas Survive and Others Die'}
# { 'category': 'Business',
#   'price': '43.14',
#   'star_rating': 1,
#   'title': 'Quench Your Own Thirst: Business Lessons Learned Over a Beer or '
#            'Two'}
# { 'category': 'Business',
#   'price': '21.00',
#   'star_rating': 3,
#   'title': 'The Art of Startup Fundraising'}
# { 'category': 'Business',
#   'price': '21.59',
#   'star_rating': 5,
#   'title': 'Born for This: How to Find the Work You Were Meant to Do'}
# { 'category': 'Business',
#   'price': '36.91',
#   'star_rating': 1,
#   'title': "The E-Myth Revisited: Why Most Small Businesses Don't Work and "
#            'What to Do About It'}
# { 'category': 'Business',
#   'price': '51.74',
#   'star_rating': 1,
#   'title': 'Rich Dad, Poor Dad'}
# { 'category': 'Business',
#   'price': '33.92',
#   'star_rating': 3,
#   'title': "The Lean Startup: How Today's Entrepreneurs Use Continuous "
#            'Innovation to Create Radically Successful Businesses'}
# {'category': 'Business', 'price': '44.88', 'star_rating': 2, 'title': 'Rework'}
# { 'category': 'Biography',
#   'price': '16.85',
#   'star_rating': 2,
#   'title': 'Louisa: The Extraordinary Life of Mrs. Adams'}
# { 'category': 'Biography',
#   'price': '21.15',
#   'star_rating': 2,
#   'title': 'Setting the World on Fire: The Brief, Astonishing Life of St. '
#            'Catherine of Siena'}
# { 'category': 'Biography',
#   'price': '39.55',
#   'star_rating': 1,
#   'title': 'The Faith of Christopher Hitchens: The Restless Soul of the '
#            "World's Most Notorious Atheist"}
# { 'category': 'Biography',
#   'price': '48.19',
#   'star_rating': 3,
#   'title': 'Benjamin Franklin: An American Life'}
# { 'category': 'Biography',
#   'price': '42.57',
#   'star_rating': 3,
#   'title': 'The Rise of Theodore Roosevelt (Theodore Roosevelt #1)'}
# { 'category': 'Thriller',
#   'price': '12.84',
#   'star_rating': 1,
#   'title': 'In Her Wake'}
# { 'category': 'Thriller',
#   'price': '23.82',
#   'star_rating': 5,
#   'title': 'The Elephant Tree'}
# { 'category': 'Thriller',
#   'price': '52.22',
#   'star_rating': 4,
#   'title': 'Behind Closed Doors'}
# { 'category': 'Thriller',
#   'price': '43.61',
#   'star_rating': 5,
#   'title': 'You (You #1)'}
# { 'category': 'Thriller',
#   'price': '13.82',
#   'star_rating': 2,
#   'title': 'The Guilty (Will Robie #4)'}
# { 'category': 'Thriller',
#   'price': '39.24',
#   'star_rating': 1,
#   'title': 'The 14th Colony (Cotton Malone #11)'}
# { 'category': 'Thriller',
#   'price': '18.32',
#   'star_rating': 2,
#   'title': 'Give It Back'}
# { 'category': 'Thriller',
#   'price': '31.49',
#   'star_rating': 4,
#   'title': 'Killing Floor (Jack Reacher #1)'}
# { 'category': 'Thriller',
#   'price': '59.71',
#   'star_rating': 3,
#   'title': 'The Bone Hunters (Lexy Vaughan & Steven Macaulay #2)'}
# { 'category': 'Thriller',
#   'price': '34.93',
#   'star_rating': 2,
#   'title': 'Far From True (Promise Falls Trilogy #2)'}
# { 'category': 'Thriller',
#   'price': '15.77',
#   'star_rating': 1,
#   'title': 'The Travelers'}
# { 'category': 'Contemporary',
#   'price': '31.77',
#   'star_rating': 1,
#   'title': 'When We Collided'}
# { 'category': 'Contemporary',
#   'price': '52.79',
#   'star_rating': 5,
#   'title': 'Someone Like You (The Harrisons #2)'}
# { 'category': 'Contemporary',
#   'price': '24.04',
#   'star_rating': 1,
#   'title': 'We Are All Completely Beside Ourselves'}
# { 'category': 'Spirituality',
#   'price': '17.66',
#   'star_rating': 5,
#   'title': 'The Four Agreements: A Practical Guide to Personal Freedom'}
# { 'category': 'Spirituality',
#   'price': '32.24',
#   'star_rating': 5,
#   'title': "The Activist's Tao Te Ching: Ancient Advice for a Modern "
#            'Revolution'}
# { 'category': 'Spirituality',
#   'price': '37.80',
#   'star_rating': 2,
#   'title': 'Chasing Heaven: What Dying Taught Me About Living'}
# { 'category': 'Spirituality',
#   'price': '20.91',
#   'star_rating': 1,
#   'title': "If I Gave You God's Phone Number....: Searching for Spirituality "
#            'in America'}
# { 'category': 'Spirituality',
#   'price': '46.33',
#   'star_rating': 2,
#   'title': 'Unreasonable Hope: Finding Faith in the God Who Brings Purpose to '
#            'Your Pain'}
# { 'category': 'Spirituality',
#   'price': '55.65',
#   'star_rating': 5,
#   'title': "A New Earth: Awakening to Your Life's Purpose"}
# { 'category': 'Academic',
#   'price': '13.12',
#   'star_rating': 2,
#   'title': 'Logan Kade (Fallen Crest High #5.5)'}
# { 'category': 'Self Help',
#   'price': '46.35',
#   'star_rating': 1,
#   'title': 'Online Marketing for Busy Authors: A Step-By-Step Guide'}
# { 'category': 'Self Help',
#   'price': '46.03',
#   'star_rating': 1,
#   'title': 'How to Be Miserable: 40 Strategies You Already Use'}
# { 'category': 'Self Help',
#   'price': '52.15',
#   'star_rating': 3,
#   'title': 'Overload: How to Unplug, Unwind, and Unleash Yourself from the '
#            'Pressure of Stress'}
# { 'category': 'Self Help',
#   'price': '12.08',
#   'star_rating': 3,
#   'title': 'You Are a Badass: How to Stop Doubting Your Greatness and Start '
#            'Living an Awesome Life'}
# { 'category': 'Self Help',
#   'price': '46.49',
#   'star_rating': 5,
#   'title': 'How to Stop Worrying and Start Living'}
# { 'category': 'Historical',
#   'price': '29.87',
#   'star_rating': 5,
#   'title': 'All the Light We Cannot See'}
# { 'category': 'Historical',
#   'price': '15.79',
#   'star_rating': 1,
#   'title': 'The Girl You Left Behind (The Girl You Left Behind #1)'}
# { 'category': 'Christian',
#   'price': '54.00',
#   'star_rating': 5,
#   'title': '(Un)Qualified: How God Uses Broken People to Do Big Things'}
# { 'category': 'Christian',
#   'price': '47.72',
#   'star_rating': 2,
#   'title': 'Crazy Love: Overwhelmed by a Relentless God'}
# { 'category': 'Christian',
#   'price': '25.77',
#   'star_rating': 1,
#   'title': 'Blue Like Jazz: Nonreligious Thoughts on Christian Spirituality'}
# { 'category': 'Suspense',
#   'price': '58.33',
#   'star_rating': 3,
#   'title': 'Silence in the Dark (Logan Point #4)'}
# { 'category': 'Short Stories',
#   'price': '35.88',
#   'star_rating': 1,
#   'title': 'The Grownup'}
# { 'category': 'Novels',
#   'price': '54.81',
#   'star_rating': 5,
#   'title': 'Suzie Snowflake: One beautiful flake (a self-esteem story)'}
# { 'category': 'Health',
#   'price': '49.05',
#   'star_rating': 3,
#   'title': 'The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and '
#            'Focus, Upgrade Your Life'}
# { 'category': 'Health',
#   'price': '54.07',
#   'star_rating': 2,
#   'title': 'Eat Fat, Get Thin'}
# { 'category': 'Health',
#   'price': '49.71',
#   'star_rating': 5,
#   'title': '10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days!'}
# { 'category': 'Health',
#   'price': '52.98',
#   'star_rating': 5,
#   'title': 'The Art and Science of Low Carbohydrate Living'}
# { 'category': 'Politics',
#   'price': '51.33',
#   'star_rating': 2,
#   'title': 'Libertarianism for Beginners'}
# { 'category': 'Politics',
#   'price': '52.65',
#   'star_rating': 4,
#   'title': 'Why the Right Went Wrong: Conservatism--From Goldwater to the Tea '
#            'Party and Beyond'}
# { 'category': 'Politics',
#   'price': '56.86',
#   'star_rating': 1,
#   'title': "Equal Is Unfair: America's Misguided Fight Against Income "
#            'Inequality'}
# { 'category': 'Cultural',
#   'price': '36.58',
#   'star_rating': 1,
#   'title': 'Amid the Chaos'}
# { 'category': 'Erotica',
#   'price': '19.19',
#   'star_rating': 5,
#   'title': 'Dark Notes'}
# { 'category': 'Crime',
#   'price': '10.97',
#   'star_rating': 1,
#   'title': 'The Long Shadow of Small Ghosts: Murder and Memory in an American '
#            'City'}
